# %%
class Dog:
    def __init__(self, name="Izabel", legs=4, speak="woof"):
        self.name = name
        self.legs = legs
        self.__speak = speak
        
    def speak(self):
        print(f"{self.name} says {self.__speak}")
# Out:
#   Cell In[2], line 2
#     def __init__(self, name="Izabel", legs=4, speak="woof")
#                                                            ^
# SyntaxError: expected ':'
