# %% [markdown]
# # Title
# ## Smaller Title

# %% [markdown]
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}

# %%
print('Doing some data science!')
# Out:
# Doing some data science!

# %%
print(1 + 1)
# Out:
# 2

# %%
def factorial(num : int):
    if not isinstance(num, int):
        raise TypeError("Give int val")

    if num == 1:
        return 1;
    else:
        return num*factorial(num-1)

# %%
factorial(3)
# Out:
# 6

# %%
a = [1,2,3]
b = a.copy()
a = [4,5,6]

a,b
# Out:
# ([4, 5, 6], [1, 2, 3])
